# %% [markdown]
# ## Instructions
# This week, you'll work on your final assignment which will be graded by your peers.
#
# This course introduced you to multiple data science tools, and in this final project, you will use Jupyter Notebook, one of the easiest tools to share publicly.
#
# Include at least 6 cells:

# %% [markdown]
# **Cell 1** (rendered as Markdown): The title should be "My Jupyter Notebook on IBM Watson Studio", in H1 header styling. The title does not need to be centered.

# %% [markdown]
# **Cell 2** (rendered as Markdown): Include your name, in bold characters. In the line below your name, write your current or desired occupation in regular font.

# %% [markdown]
# **Cell 3** (rendered as Markdown): In italic formatting, write one or two sentences about why you are interested in data science. For example, you can start your first sentence with "I am interested in data science because ...".

# %% [markdown]
# **Cell 4** (rendered as Markdown): In H3 header styling, explain in a short sentence what your code is supposed to do in Cell 5.

# %% [markdown]
# **Cell 5** (code cell): Your code, as described in Cell 4. It must be executed and must display an output. Try to keep the code simple (it can even be "1 + 1").

# %% [markdown]
# **Cell 6** (rendered as Markdown): Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.

# %% [markdown]
# #  1 - My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **2 - Jean Charlles**
#
# I want to be a data science developer

# %% [markdown]
# *3 - I am interested in studying data science because I like data. For a long time I solved some problems in excel and I always had the vision that I could do more with a programming language. That's why I want to migrate from an administrative career to technology. I have been studying for a long time and I hope this year to be able to apply for vacancies.*

# %% [markdown]
# ### 4 - The code below will perform a simple math operation

# %%
# 5
1 + 1
# Out:
# 2

# %% [markdown]
# # 6 What I learned with IBM and Coursera
#
# ### IBM Cloud Pak for Data
# ***
#
# - Data Asset exChange - IBM for Developer
# - Machine Learning
#
# ---
#
# *Learning*:<br>
# 1. Tools for Data Science
# 2. Watson Studio
# 3. Python
# 4. R
#
# ---
#
#
# | Cloud IBM | Services |
# | ----| ----|
# | Assets  | Storage |
# | Projects| Management |
#
# ---
#
# > A full stack cloud platform
#
# ---
#
# <html>
#     <b>Example of code</b><br>
#     <code>python app.py</code>
# </html
